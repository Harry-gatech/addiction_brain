# %% [markdown]
# *testing the datas before integrating in the pipeline*

# %%
import pandas as pd 
import numpy as np 
from addiction_brain.network_hop import run_trajectory

# %%
node = pd.read_csv(r"Data\STRING_node.csv")
edge = pd.read_csv(r"Data\STRING_edge.csv")

# %%
print(node[['name']])
# Out:
#                       name
# 0     9606.ENSP00000278937
# 1     9606.ENSP00000251472
# 2     9606.ENSP00000240361
# 3     9606.ENSP00000379571
# 4     9606.ENSP00000419619
# ...                    ...
# 2233  9606.ENSP00000256682
# 2234  9606.ENSP00000331342
# 2235  9606.ENSP00000281419
# 2236  9606.ENSP00000307634
# 2237  9606.ENSP00000000233
#
# [2238 rows x 1 columns]
